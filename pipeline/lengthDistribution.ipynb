# %%
data = numpy.loadtxt('lengths.txt')
hist(data, bins=100)
xlabel('Sequence lengths of my favourite sequences')
ylabel('N sequences with that length')
title('Sequence length spectrum')
savefig('hist.pdf')

# %%
print "Hello, world"
# Out:
# Hello, world
